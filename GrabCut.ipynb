# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv.imread('./data/bounding_box_img1.jpg')
mask = np.zeros(img.shape[:2],np.uint8)
mask[160:290,250:460] = 1
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
#rect = (240,150,460,330) # x, y, w, h 
rect = (50,50,450,290) # original

cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img2 = img*mask2[:,:,np.newaxis]
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(mask2)
plt.title('Grabcut')
plt.show()

# %%
# newmask is the mask image I manually labelled
mask = np.zeros(img.shape[:2],np.uint8)
mask[160:290,250:460] = 1
mask, bgdModel, fgdModel = cv.grabCut(img,mask,None,bgdModel,fgdModel,5,cv.GC_INIT_WITH_MASK)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img2 = img*mask[:,:,np.newaxis]
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(mask2)
plt.title('Grabcut')
plt.show()

# %%
crop_img = img[160:290,250:460] # y, h, x, w
#crop_img = img[150:330,240:460]
mask = np.zeros(img.shape[:2],np.uint8)
plt.imshow(crop_img)
plt.show()
